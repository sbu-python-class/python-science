# %% [markdown]
# # Clustering

# %% [markdown]
# [Clustering](https://en.wikipedia.org/wiki/Cluster_analysis) seeks to group data into clusters based on their properties and then allow us to predict which cluster a new member belongs.

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# We'll use a dataset generator that is part of [scikit-learn](https://scikit-learn.org/stable/index.html) called [`make_moons`](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_moons.html).  This generates data that falls into 2 different sets with a shape that looks like half-moons.

# %%
from sklearn import datasets

# %%
def generate_data():
    xvec, val = datasets.make_moons(200, noise=0.2)

    # encode the output to be 2 elements
    x = []
    v = []
    for xv, vv in zip(xvec, val):
        x.append(np.array(xv))
        v.append(vv)

    return np.array(x), np.array(v)

# %%
x, v = generate_data()

# %% [markdown]
# Let's look at a point and it's value

# %%
print(f"x = {x[0]}, value = {v[0]}")
# Out:
# x = [-0.89111319  0.50175619], value = 0

# %% [markdown]
# Now let's plot the data

# %%
def plot_data(x, v):
    xpt = [q[0] for q in x]
    ypt = [q[1] for q in x]

    fig, ax = plt.subplots()
    ax.scatter(xpt, ypt, s=40, c=v, cmap="viridis")
    ax.set_aspect("equal")
    return fig

# %%
fig = plot_data(x, v)

# %% [markdown]
# We want to partition this domain into 2 regions, such that when we come in with a new point, we know which group it belongs to.

# %% [markdown]
# First we setup and train our network

# %%
from keras.models import Sequential
from keras.layers import Dense, Dropout, Activation, Input
from keras.optimizers import RMSprop

# %%
model = Sequential()
model.add(Input(shape=(2,)))
model.add(Dense(50, activation="relu"))
model.add(Dense(20, activation="relu"))
model.add(Dense(1, activation="sigmoid"))

# %%
rms = RMSprop()
model.compile(loss='binary_crossentropy',
              optimizer=rms, metrics=['accuracy'])

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ dense (Dense)                   │ (None, 50)             │           150 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 20)             │         1,020 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 1)              │            21 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 1,191 (4.65 KB)
#  Trainable params: 1,191 (4.65 KB)
#  Non-trainable params: 0 (0.00 B)

# %% [markdown]
# We seem to need a lot of epochs here to get a good result

# %%
epochs = 200
results = model.fit(x, v, batch_size=50, epochs=epochs, verbose=2)
# Out:
# Epoch 1/200
# 4/4 - 0s - 7ms/step - accuracy: 0.8950 - loss: 0.2425
# Epoch 2/200
# 4/4 - 0s - 27ms/step - accuracy: 0.8900 - loss: 0.2427
# Epoch 3/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9000 - loss: 0.2416
# Epoch 4/200
# 4/4 - 0s - 7ms/step - accuracy: 0.8900 - loss: 0.2402
# Epoch 5/200
# 4/4 - 0s - 10ms/step - accuracy: 0.9050 - loss: 0.2429
# Epoch 6/200
# 4/4 - 0s - 7ms/step - accuracy: 0.8900 - loss: 0.2385
# Epoch 7/200
# 4/4 - 0s - 8ms/step - accuracy: 0.8900 - loss: 0.2408
# Epoch 8/200
# 4/4 - 0s - 8ms/step - accuracy: 0.8950 - loss: 0.2368
# Epoch 9/200
# 4/4 - 0s - 10ms/step - accuracy: 0.9000 - loss: 0.2365
# Epoch 10/200
# 4/4 - 0s - 24ms/step - accuracy: 0.9000 - loss: 0.2365
# Epoch 11/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9000 - loss: 0.2356
# Epoch 12/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9050 - loss: 0.2349
# Epoch 13/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9050 - loss: 0.2330
# Epoch 14/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9000 - loss: 0.2343
# Epoch 15/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9050 - loss: 0.2330
# Epoch 16/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9050 - loss: 0.2315
# Epoch 17/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9050 - loss: 0.2300
# Epoch 18/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9050 - loss: 0.2294
# Epoch 19/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9050 - loss: 0.2285
# Epoch 20/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9000 - loss: 0.2316
# Epoch 21/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9050 - loss: 0.2294
# Epoch 22/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9050 - loss: 0.2266
# Epoch 23/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9100 - loss: 0.2272
# Epoch 24/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9050 - loss: 0.2251
# Epoch 25/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9050 - loss: 0.2240
# Epoch 26/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9100 - loss: 0.2232
# Epoch 27/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9100 - loss: 0.2224
# Epoch 28/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9100 - loss: 0.2216
# Epoch 29/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9100 - loss: 0.2208
# Epoch 30/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9100 - loss: 0.2226
# Epoch 31/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9100 - loss: 0.2202
# Epoch 32/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9100 - loss: 0.2207
# Epoch 33/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9100 - loss: 0.2170
# Epoch 34/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9100 - loss: 0.2170
# Epoch 35/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9150 - loss: 0.2162
# Epoch 36/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9100 - loss: 0.2147
# Epoch 37/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9100 - loss: 0.2138
# Epoch 38/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9100 - loss: 0.2139
# Epoch 39/200
# 4/4 - 0s - 59ms/step - accuracy: 0.9100 - loss: 0.2121
# Epoch 40/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9100 - loss: 0.2114
# Epoch 41/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9100 - loss: 0.2099
# Epoch 42/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9150 - loss: 0.2087
# Epoch 43/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9150 - loss: 0.2106
# Epoch 44/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9150 - loss: 0.2084
# Epoch 45/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9200 - loss: 0.2059
# Epoch 46/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9200 - loss: 0.2056
# Epoch 47/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9200 - loss: 0.2047
# Epoch 48/200
# 4/4 - 0s - 23ms/step - accuracy: 0.9200 - loss: 0.2031
# Epoch 49/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9200 - loss: 0.2029
# Epoch 50/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9200 - loss: 0.2030
# Epoch 51/200
# 4/4 - 0s - 11ms/step - accuracy: 0.9200 - loss: 0.1998
# Epoch 52/200
# 4/4 - 0s - 8ms/step - accuracy: 0.9200 - loss: 0.2004
# Epoch 53/200
# 4/4 - 0s - 8ms/step - accuracy: 0.9200 - loss: 0.1981
# Epoch 54/200
# 4/4 - 0s - 8ms/step - accuracy: 0.9200 - loss: 0.1975
# Epoch 55/200
# 4/4 - 0s - 8ms/step - accuracy: 0.9200 - loss: 0.1958
# Epoch 56/200
# 4/4 - 0s - 26ms/step - accuracy: 0.9250 - loss: 0.1964
# Epoch 57/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9250 - loss: 0.1954
# Epoch 58/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9200 - loss: 0.1937
# Epoch 59/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9250 - loss: 0.1935
# Epoch 60/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9200 - loss: 0.1909
# Epoch 61/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9200 - loss: 0.1915
# Epoch 62/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9200 - loss: 0.1896
# Epoch 63/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9250 - loss: 0.1909
# Epoch 64/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9250 - loss: 0.1875
# Epoch 65/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9250 - loss: 0.1880
# Epoch 66/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9200 - loss: 0.1850
# Epoch 67/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9200 - loss: 0.1848
# Epoch 68/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9250 - loss: 0.1830
# Epoch 69/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9300 - loss: 0.1821
# Epoch 70/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9250 - loss: 0.1816
# Epoch 71/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9250 - loss: 0.1827
# Epoch 72/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9250 - loss: 0.1800
# Epoch 73/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9300 - loss: 0.1784
# Epoch 74/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9300 - loss: 0.1770
# Epoch 75/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9350 - loss: 0.1759
# Epoch 76/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9350 - loss: 0.1761
# Epoch 77/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9350 - loss: 0.1747
# Epoch 78/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9400 - loss: 0.1733
# Epoch 79/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9400 - loss: 0.1723
# Epoch 80/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9400 - loss: 0.1722
# Epoch 81/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9400 - loss: 0.1702
# Epoch 82/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1695
# Epoch 83/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9350 - loss: 0.1693
# Epoch 84/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9400 - loss: 0.1677
# Epoch 85/200
# 4/4 - 0s - 56ms/step - accuracy: 0.9400 - loss: 0.1661
# Epoch 86/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9450 - loss: 0.1654
# Epoch 87/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1650
# Epoch 88/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1631
# Epoch 89/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9400 - loss: 0.1628
# Epoch 90/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1611
# Epoch 91/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1601
# Epoch 92/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1589
# Epoch 93/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9400 - loss: 0.1612
# Epoch 94/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1576
# Epoch 95/200
# 4/4 - 0s - 8ms/step - accuracy: 0.9450 - loss: 0.1559
# Epoch 96/200
# 4/4 - 0s - 8ms/step - accuracy: 0.9400 - loss: 0.1566
# Epoch 97/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9450 - loss: 0.1543
# Epoch 98/200
# 4/4 - 0s - 11ms/step - accuracy: 0.9450 - loss: 0.1543
# Epoch 99/200
# 4/4 - 0s - 8ms/step - accuracy: 0.9450 - loss: 0.1524
# Epoch 100/200
# 4/4 - 0s - 9ms/step - accuracy: 0.9450 - loss: 0.1521
# Epoch 101/200
# 4/4 - 0s - 9ms/step - accuracy: 0.9500 - loss: 0.1512
# Epoch 102/200
# 4/4 - 0s - 25ms/step - accuracy: 0.9450 - loss: 0.1498
# Epoch 103/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9450 - loss: 0.1492
# Epoch 104/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1473
# Epoch 105/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9450 - loss: 0.1476
# Epoch 106/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1463
# Epoch 107/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1463
# Epoch 108/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1447
# Epoch 109/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9450 - loss: 0.1444
# Epoch 110/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1440
# Epoch 111/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1417
# Epoch 112/200
# 4/4 - 0s - 8ms/step - accuracy: 0.9450 - loss: 0.1414
# Epoch 113/200
# 4/4 - 0s - 8ms/step - accuracy: 0.9450 - loss: 0.1396
# Epoch 114/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9450 - loss: 0.1390
# Epoch 115/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1386
# Epoch 116/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9450 - loss: 0.1370
# Epoch 117/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1369
# Epoch 118/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1361
# Epoch 119/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1354
# Epoch 120/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1348
# Epoch 121/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1335
# Epoch 122/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1330
# Epoch 123/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1320
# Epoch 124/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9500 - loss: 0.1308
# Epoch 125/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1329
# Epoch 126/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1299
# Epoch 127/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1282
# Epoch 128/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1283
# Epoch 129/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1279
# Epoch 130/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9450 - loss: 0.1272
# Epoch 131/200
# 4/4 - 0s - 56ms/step - accuracy: 0.9450 - loss: 0.1261
# Epoch 132/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9450 - loss: 0.1242
# Epoch 133/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1237
# Epoch 134/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1239
# Epoch 135/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9500 - loss: 0.1222
# Epoch 136/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1215
# Epoch 137/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9500 - loss: 0.1209
# Epoch 138/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9500 - loss: 0.1194
# Epoch 139/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9450 - loss: 0.1204
# Epoch 140/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9500 - loss: 0.1197
# Epoch 141/200
# 4/4 - 0s - 24ms/step - accuracy: 0.9500 - loss: 0.1179
# Epoch 142/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9500 - loss: 0.1172
# Epoch 143/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9500 - loss: 0.1161
# Epoch 144/200
# 4/4 - 0s - 10ms/step - accuracy: 0.9500 - loss: 0.1174
# Epoch 145/200
# 4/4 - 0s - 8ms/step - accuracy: 0.9500 - loss: 0.1148
# Epoch 146/200
# 4/4 - 0s - 8ms/step - accuracy: 0.9500 - loss: 0.1138
# Epoch 147/200
# 4/4 - 0s - 8ms/step - accuracy: 0.9500 - loss: 0.1134
# Epoch 148/200
# 4/4 - 0s - 26ms/step - accuracy: 0.9500 - loss: 0.1129
# Epoch 149/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9500 - loss: 0.1112
# Epoch 150/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9500 - loss: 0.1100
# Epoch 151/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9500 - loss: 0.1105
# Epoch 152/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9500 - loss: 0.1093
# Epoch 153/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9500 - loss: 0.1091
# Epoch 154/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9500 - loss: 0.1075
# Epoch 155/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9500 - loss: 0.1062
# Epoch 156/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9500 - loss: 0.1058
# Epoch 157/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9500 - loss: 0.1070
# Epoch 158/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9500 - loss: 0.1042
# Epoch 159/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9500 - loss: 0.1038
# Epoch 160/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9500 - loss: 0.1052
# Epoch 161/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9500 - loss: 0.1025
# Epoch 162/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9500 - loss: 0.1020
# Epoch 163/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9500 - loss: 0.1027
# Epoch 164/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9500 - loss: 0.1006
# Epoch 165/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9500 - loss: 0.0996
# Epoch 166/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9500 - loss: 0.1001
# Epoch 167/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9550 - loss: 0.0994
# Epoch 168/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9500 - loss: 0.0986
# Epoch 169/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9500 - loss: 0.0996
# Epoch 170/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9500 - loss: 0.0977
# Epoch 171/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9500 - loss: 0.0978
# Epoch 172/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9500 - loss: 0.0959
# Epoch 173/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9500 - loss: 0.0967
# Epoch 174/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9500 - loss: 0.0952
# Epoch 175/200
# 4/4 - 0s - 8ms/step - accuracy: 0.9500 - loss: 0.0966
# Epoch 176/200
# 4/4 - 0s - 8ms/step - accuracy: 0.9500 - loss: 0.0941
# Epoch 177/200
# 4/4 - 0s - 58ms/step - accuracy: 0.9550 - loss: 0.0951
# Epoch 178/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9500 - loss: 0.0936
# Epoch 179/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9500 - loss: 0.0934
# Epoch 180/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9500 - loss: 0.0949
# Epoch 181/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9500 - loss: 0.0916
# Epoch 182/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9500 - loss: 0.0913
# Epoch 183/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9500 - loss: 0.0906
# Epoch 184/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9550 - loss: 0.0896
# Epoch 185/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9500 - loss: 0.0903
# Epoch 186/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9550 - loss: 0.0895
# Epoch 187/200
# 4/4 - 0s - 25ms/step - accuracy: 0.9500 - loss: 0.0901
# Epoch 188/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9500 - loss: 0.0905
# Epoch 189/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9550 - loss: 0.0890
# Epoch 190/200
# 4/4 - 0s - 10ms/step - accuracy: 0.9550 - loss: 0.0862
# Epoch 191/200
# 4/4 - 0s - 8ms/step - accuracy: 0.9550 - loss: 0.0865
# Epoch 192/200
# 4/4 - 0s - 9ms/step - accuracy: 0.9550 - loss: 0.0853
# Epoch 193/200
# 4/4 - 0s - 9ms/step - accuracy: 0.9600 - loss: 0.0862
# Epoch 194/200
# 4/4 - 0s - 27ms/step - accuracy: 0.9550 - loss: 0.0853
# Epoch 195/200
# 4/4 - 0s - 8ms/step - accuracy: 0.9550 - loss: 0.0839
# Epoch 196/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9550 - loss: 0.0834
# Epoch 197/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9550 - loss: 0.0844
# Epoch 198/200
# 4/4 - 0s - 6ms/step - accuracy: 0.9550 - loss: 0.0834
# Epoch 199/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9550 - loss: 0.0833
# Epoch 200/200
# 4/4 - 0s - 7ms/step - accuracy: 0.9550 - loss: 0.0836

# %%
score = model.evaluate(x, v, verbose=0)
print(f"score = {score[0]}")
print(f"accuracy = {score[1]}")
# Out:
# score = 0.08107449859380722
# accuracy = 0.9549999833106995

# %% [markdown]
# Let's look at a prediction.  We need to feed in a single point as an array of shape `(N, 2)`, where `N` is the number of points

# %%
res = model.predict(np.array([[-2, 2]]))
res
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step
# array([[5.6428496e-29]], dtype=float32)

# %% [markdown]
# We see that we get a floating point number.  We will need to convert this to 0 or 1 by rounding.

# %% [markdown]
# Let's plot the partitioning

# %%
M = 128
N = 128

xmin = -1.75
xmax = 2.5
ymin = -1.25
ymax = 1.75

xpt = np.linspace(xmin, xmax, M)
ypt = np.linspace(ymin, ymax, N)

# %% [markdown]
# To make the prediction go faster, we want to feed in a vector of these points, of the form:
# ```
# [[xpt[0], ypt[0]],
#  [xpt[1], ypt[1]],
#  ...
# ]
# ```

# %% [markdown]
# We can see that this packs them into the vector

# %%
pairs = np.array(np.meshgrid(xpt, ypt)).T.reshape(-1, 2)
pairs[0]
# Out:
# array([-1.75, -1.25])

# %% [markdown]
# Now we do the prediction.  We will get a vector out, which we reshape to match the original domain.

# %%
res = model.predict(pairs, verbose=0)
res.shape = (M, N)

# %% [markdown]
# Finally, round to 0 or 1

# %%
domain = np.where(res > 0.5, 1, 0)

# %% [markdown]
# and we can plot the data

# %%
fig, ax = plt.subplots()
ax.imshow(domain.T, origin="lower",
          extent=[xmin, xmax, ymin, ymax], alpha=0.25)
xpt = [q[0] for q in x]
ypt = [q[1] for q in x]

ax.scatter(xpt, ypt, s=40, c=v, cmap="viridis")
